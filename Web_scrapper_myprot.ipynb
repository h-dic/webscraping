# %%
import requests
page_1 = requests.get("https://fr.myprotein.com/nutrition/protein.list")
page_2 = requests.get("https://fr.myprotein.com/nutrition/protein.list?pageNumber=2")

# %%
pages = page_1.content + page_2.content

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(pages,'html.parser')

# %%
proteines_name = soup.find_all('h2', class_ ='athenaProductBlock_productName')
proteines_price_from = soup.find_all('span', class_='athenaProductBlock_fromValue')
proteines_price_value = soup.find_all('span', class_='athenaProductBlock_priceValue')

# %%
for item in list(proteines_price_from):
    item['class']='price'

for item in list(proteines_price_value):
    item['class']='price'
    
proteines_price = soup.find_all('span', class_='price')

# %%
list_proteines_name = [item.get_text()[1:-1] for item in list(proteines_name)]
list_proteines_price = [item.get_text()[:-2] for item in list(proteines_price)]

# %%
print(list_proteines_name)
print(list_proteines_price)
# Out:
# ['Impact Whey Protein', 'Clear Whey Isolate', 'Clear Vegan Protein', 'Impact Whey Isolate', 'Impact Diet Whey', 'Hard Gainer Extreme', 'Weight Gainer', 'THE Whey™', 'Impact Native Whey Isolate', 'Total Protein', 'Mélange de protéines végétales', 'Caséine micellaire', 'Substitut de repas protéiné', 'Mélange performance tout-en-un', 'Isolat de protéine de soja', 'Mélange protéiné allégé', 'Impact Whey Protein Elite', 'ISO: PRO', 'Chocolat Chaud Protéiné', 'Peptide de Collagène Hydrolysé', 'Isolat de protéine de pois', 'THE Diet', 'Protéine de Whey Bio', "Blanc d'oeuf en poudre", 'Mélange tout-en-un Vegan', 'Caséine Micellaire Elite', 'Formule Tout-en-un Elite', 'Protéine de whey hydrolysée', 'Impact Whey Protein 250g', 'THE Whey+', 'Mélange performance extreme', 'THE Gainer™', 'Protéine de riz brun', 'Protéine de lait onctueuse', 'Eau protéinée', 'Caséinate de calcium', 'Protéine de chanvre bio', "Jaune d'oeuf en poudre", 'Substitut de repas', 'Caséine PeptoPro', 'Mocha Protéiné', 'Petit-déjeuner complet', 'Protéines végétaliennes et légumes verts']
# ['7,99', '14,99', '27,99', '25,69', '6,99', '27,79', '26,99', '24,69', '31,99', '20,99', '13,99', '20,79', '4,99', '47,19', '5,99', '9,69', '38,39', '29,89', '17,19', '16,99', '12,99', '72,99', '19,39', '21,09', '38,29', '25,99', '42,89', '27,49', '8,95', '28,99', '60,59', '80,99', '18,99', '42,79', '23,99', '21,09', '15,99', '20,99', '24,39', '52,59', '17,99', '31,99', '8,99']

# %%
len(list_proteines_price)
# Out:
# 43

# %%
import pandas as pd

# %%
proteins = pd.DataFrame({
    "name":list_proteines_name,
    "price":list_proteines_price
})

# %%
proteins
# Out:
#                                         name  price
# 0                        Impact Whey Protein   7,99
# 1                         Clear Whey Isolate  14,99
# 2                        Clear Vegan Protein  27,99
# 3                        Impact Whey Isolate  25,69
# 4                           Impact Diet Whey   6,99
# 5                        Hard Gainer Extreme  27,79
# 6                              Weight Gainer  26,99
# 7                                  THE Whey™  24,69
# 8                 Impact Native Whey Isolate  31,99
# 9                              Total Protein  20,99
# 10            Mélange de protéines végétales  13,99
# 11                        Caséine micellaire  20,79
# 12               Substitut de repas protéiné   4,99
# 13            Mélange performance tout-en-un  47,19
# 14                Isolat de protéine de soja   5,99
# 15                   Mélange protéiné allégé   9,69
# 16                 Impact Whey Protein Elite  38,39
# 17                                  ISO: PRO  29,89
# 18                   Chocolat Chaud Protéiné  17,19
# 19            Peptide de Collagène Hydrolysé  16,99
# 20                Isolat de protéine de pois  12,99
# 21                                  THE Diet  72,99
# 22                      Protéine de Whey Bio  19,39
# 23                    Blanc d'oeuf en poudre  21,09
# 24                  Mélange tout-en-un Vegan  38,29
# 25                  Caséine Micellaire Elite  25,99
# 26                  Formule Tout-en-un Elite  42,89
# 27               Protéine de whey hydrolysée  27,49
# 28                  Impact Whey Protein 250g   8,95
# 29                                 THE Whey+  28,99
# 30               Mélange performance extreme  60,59
# 31                               THE Gainer™  80,99
# 32                      Protéine de riz brun  18,99
# 33                Protéine de lait onctueuse  42,79
# 34                             Eau protéinée  23,99
# 35                      Caséinate de calcium  21,09
# 36                   Protéine de chanvre bio  15,99
# 37                    Jaune d'oeuf en poudre  20,99
# 38                        Substitut de repas  24,39
# 39                          Caséine PeptoPro  52,59
# 40                            Mocha Protéiné  17,99
# 41                    Petit-déjeuner complet  31,99
# 42  Protéines végétaliennes et légumes verts   8,99

# %%
proteins.to_csv(r'proteins_and_price.csv', index=False)
